# %% [markdown]
# <h1>1. Basics</h1>

# %%
print('Hello world !')
# Out:
# Hello world !

# %%
def greet(name):
    return f'Hello,{name}!'

# %%
x=10
y=x
print(y)
# Out:
# 10

# %%
x=15
print(y)
# Out:
# 10

# %% [markdown]
# <h1>2. Data types</h1>

# %% [markdown]
# #object types /Data Types

# %% [markdown]
# -Number : 1,2,3,4 fraction 3.5,10.3 Complex 2+3j ,0b111,ecimal

# %%
mylist1=[1,2,3,4]
mylist2=mylist1
mylist1='vasa'
# Out:
# [1, 2, 3, 4]

# %%
h1=[1,2,3]
h2=h1[1:]
h2
# Out:
# [2, 3]

# %%
n=[1,2,3,4,5]
m=n
m==n
# Out:
# True

# %%
n=[1,2,3,4,5]
m=[1,2,3,4,5]
print(m==n)
print(m is n)
# Out:
# True
# False
