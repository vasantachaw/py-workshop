# %% [markdown]
# <h1>1. Basics</h1>

# %%
print("Hello world !")
# Out:
# Hello world !

# %%
def greet(name):
    return f"Hello,{name}!"

# %%
x = 10
y = x
print(y)
# Out:
# 10

# %%
x = 15
print(y)
# Out:
# 10

# %% [markdown]
# <h1>2. Data types</h1>

# %% [markdown]
# #object types /Data Types

# %% [markdown]
# -Number : 1,2,3,4 fraction 3.5,10.3 Complex 2+3j ,0b111,ecimal

# %%
mylist1 = [1, 2, 3, 4]
mylist2 = mylist1
mylist1 = "vasa"
# Out:
# [1, 2, 3, 4]

# %%
h1 = [1, 2, 3]
h2 = h1[1:]
h2
# Out:
# [2, 3]

# %%
n = [1, 2, 3, 4, 5]
m = n
m == n
# Out:
# True

# %%
n = [1, 2, 3, 4, 5]
m = [1, 2, 3, 4, 5]
print(m == n)
print(m is n)
# Out:
# True
# False

# %%
x, y, z = 2, 3, 4
print(x + y)
# Out:
# 5

# %%
print((x + y) * z)
# Out:
# 20

# %%
x, y, z
# Out:
# (2, 3, 4)

# %%
food_item = input("Enter Food Item Name : ")


def getPrice(food_item):
    if food_item == "burger":
        return 100
    elif food_item == "pizza":
        return 200
    elif food_item == "juice":
        return 50
    elif food_item == "tofu":
        return 150


print(getPrice(food_item))
# Out:
# 150

# %%
food_name = input("Enter Food Name : ")
food_name_dict = {"burger": 100, "pizza": 300, "juice": 50, "momo": 120}


def get_price(food_name):
    return food_name_dict.get(food_name, 0)


print(get_price(food_name))
# Out:
# 120

# %%
type((x, y, z))
# Out:
# tuple

# %%
k = x, y, z
type(k)
# Out:
# tuple

# %%
y % 2
# Out:
# 1

# %%
z**2
# Out:
# 16

# %%
2**100
# Out:
# 1267650600228229401496703205376

# %%
result = 1 / 3.0
print(result)
# Out:
# 0.3333333333333333

# %%
repr("Hello")
# Out:
# "'Hello'"

# %%
str("Hello")
# Out:
# 'Hello'

# %%
print("Hello")
# Out:
# Hello

# %%
1 > 2
# Out:
# False

# %%
5.0 == 5.0
# Out:
# True

# %%
4.0 != 5.0
# Out:
# True

# %%
x, y, z = 1, 2, 3

# %%
x < y < z
# Out:
# True

# %%
x < y and y < z
# Out:
# True

# %%
1 == 2 < 3  # True =1
# Out:
# False

# %%
import math

math.floor(3.5)
# Out:
# 3

# %%
math.floor(3.9)
# Out:
# 3

# %%
math.floor(-3.2)
# Out:
# -4

# %%
math.floor(-3.9)
# Out:
# -4

# %%
math.ceil(3.5)
# Out:
# 4

# %%
math.ceil(-3.2)
# Out:
# -3

# %%
math.trunc(3.5)
# Out:
# 3

# %%
math.trunc(3.9)
# Out:
# 3

# %%
math.trunc(-3.3)
# Out:
# -3

# %%
88888888888888888888888888888888888 * 2.1
# Out:
# 1.8666666666666665e+35

# %%
2 + 1j
# Out:
# (2+1j)

# %%
(2 + 1j) * 3
# Out:
# (6+3j)

# %%
0o20
# Out:
# 16

# %%
0xFF
# Out:
# 255

# %%
0b1000
# Out:
# 8

# %%
oct(16)
# Out:
# '0o20'

# %%
hex(255)
# Out:
# '0xff'

# %%
bin(8)
# Out:
# '0b1000'

# %%
int("100", 2)
# Out:
# 4

# %%
int("100", 8)
# Out:
# 64

# %%
int("10", 16)
# Out:
# 16

# %%
# bitwiseoperators
x = 1
x << 2
# Out:
# 4

# %%
import random

random.random()
# Out:
# 0.46482423949407414

# %%
random.randint(1, 10)
# Out:
# 2

# %%
random.choice([random.randint(1, 10)])
# Out:
# 8

# %%
random.choice(["apple", "banana", "cherry"])
# Out:
# 'apple'

# %%
listat = ["apple", "banana", "cherry"]
random.shuffle(listat)
listat
# Out:
# ['apple', 'cherry', 'banana']

# %%
listat
# Out:
# ['apple', 'cherry', 'banana']

# %%
listat
# Out:
# ['apple', 'cherry', 'banana']

# %%
0.1 + 0.1 + 0.4
# Out:
# 0.6000000000000001

# %%
(0.1 + 0.1 + 0.1) - 0.3
# Out:
# 5.551115123125783e-17

# %%
from decimal import Decimal

Decimal("0.1") + Decimal("0.1") + Decimal("0.1") - Decimal("0.3")
# Out:
# Decimal('0.0')

# %%
from fractions import Fraction

fun = Fraction(2, 7)
fun
# Out:
# Fraction(2, 7)

# %%
setone = {1, 2, 3, 4}
setone & {1, 3}
# Out:
# {1, 3}

# %%
setone | {1, 2}
# Out:
# {1, 2, 3, 4}

# %%
setone | {1, 3, 5, 7}
# Out:
# {1, 2, 3, 4, 5, 7}

# %%
setone
# Out:
# {1, 2, 3, 4}

# %%
setone - {1, 2, 3, 4}
# Out:
# set()

# %%
type({})
# Out:
# dict

# %%
type(True)
# Out:
# bool

# %%
True == 1
# Out:
# True

# %%
True is 1
# Out:
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# <>:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
# C:\Users\Basant\AppData\Local\Temp\ipykernel_14792\812578685.py:1: SyntaxWarning: "is" with a literal. Did you mean "=="?
#   True is 1
# False

# %%
False == 0
# Out:
# True

# %%
True + 4
# Out:
# 5

# %%
False * 6
# Out:
# 0

# %%
tea_varieties = ["Black", "Green", "Oolang", "White"]
tea_varieties
# Out:
# ['Black', 'Green', 'Oolang', 'White']

# %%
print(tea_varieties)
# Out:
# ['Black', 'Green', 'Oolang', 'White']

# %%
print(tea_varieties[1])
# Out:
# Green

# %%
print(tea_varieties[-1])
# Out:
# White

# %%
print(tea_varieties[1][2:])
# Out:
# een

# %%
print(tea_varieties[1::2][1][:2])
# Out:
# Wh

# %%
tea_varieties = ["Black", "Green", "Oolang", "White"]
tea_varieties
# Out:
# ['Black', 'Green', 'Oolang', 'White']

# %%
tea_varieties[1:2]
# Out:
# ['Green']

# %%
tea_varieties
# Out:
# ['Black', 'Green', 'Oolang', 'White']

# %%
tea_varieties[1:2] = ["lemon"]
tea_varieties
# Out:
# ['Black', 'lemon', 'Oolang', 'White']

# %%
tea_varieties[1:2] = "lemon"
tea_varieties
# Out:
# ['Black', 'lemon', 'e', 'm', 'o', 'n', 'Oolang', 'White']

# %%
tea_varieties
# Out:
# ['Black', 'lemon', 'Oolang', 'White']

# %%
tea_varieties[1:1]
# Out:
# []

# %%
tea_varieties[2:2]
# Out:
# []

# %%
tea_varieties[1:1] = ["test", "test"]

# %%
tea_varieties
# Out:
# ['Black', 'test', 'test', 'lemon', 'Oolang', 'White']

# %%
tea_varieties[1:3]
# Out:
# ['test', 'test']

# %%
tea_varieties[1:3] = []
tea_varieties
# Out:
# ['Black', 'lemon', 'Oolang', 'White']

# %%
for tea in tea_varieties:
    print(tea, end=" ")
# Out:
# Black lemon Oolang White

# %%
if "Oolang" in tea_varieties:
    print("I have Oolang tea")
else:
    print("I have not Oolang tea")
# Out:
# I have Oolang tea

# %%
t = "Taj"
if t in tea_varieties:
    print(f"I have {t} tea")
else:
    print(f"I have not {t} tea")
# Out:
# I have not Taj tea

# %%
tea_varieties.append("Taj")

# %%
tea_varieties
# Out:
# ['Black', 'lemon', 'Oolang', 'White', 'Taj']

# %%
tea_varieties.pop()
# Out:
# 'Taj'

# %%
tea_varieties
# Out:
# ['Black', 'lemon', 'Oolang', 'White']

# %%
tea_varieties.remove("lemon")
tea_varieties
# Out:
# ['Black', 'Oolang', 'White']

# %%
tea_varieties.insert(1, "Green")
tea_varieties
# Out:
# ['Black', 'Green', 'Oolang', 'White']

# %%
sqr_num = [x**2 for x in range(10)]

# %%
sqr_num
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %%
range(10)
# Out:
# range(0, 10)

# %%
y = range(10)
y
# Out:
# range(0, 10)

# %% [markdown]
# <h1>Dictionaries</h1>

# %% [markdown]
# dict

# %%
prices = {1: "Apple", 2: "Banana", 3: "Mango"}

# %%
prices
# Out:
# {1: 'Apple', 2: 'Banana', 3: 'Mango'}

# %%
prices[1]
# Out:
# 'Apple'

# %%
prices[3]
# Out:
# 'Mango'

# %%
prices.get(1)
# Out:
# 'Apple'

# %%
prices["1"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[85], line 1
# ----> 1 prices['1']
#
# KeyError: '1'

# %%
prices[1] = "Gova"
prices
# Out:
# {1: 'Gova', 2: 'Banana', 3: 'Mango'}

# %%
for pr in prices:
    print(pr, prices[pr])
# Out:
# 1 Gova
# 2 Banana
# 3 Mango

# %%
for key, value in prices.items():
    print(key, value)
# Out:
# 1 Gova
# 2 Banana
# 3 Mango

# %%
if 1 in prices:
    print("i have a Gova")
# Out:
# i have a Gova

# %%
prices
# Out:
# {1: 'Gova', 2: 'Banana', 3: 'Mango'}

# %%
prices[4] = "Orange"

# %%
prices
# Out:
# {1: 'Gova', 2: 'Banana', 3: 'Mango', 4: 'Orange'}

# %%
prices.pop(4)
# Out:
# 'Orange'

# %%
prices.popitem()
# Out:
# (3, 'Mango')

# %%
del prices[1]

# %%
prices
# Out:
# {2: 'Banana'}

# %%
prices_copy = prices.copy()

# %%
tea_shop = {
    "chai": {"Masala": "spicy", "Ginger": "zesty"},
    "Tea": {"Green": "Mind", "Black": "strong"},
}

# %%
tea_shop
# Out:
# {'chai': {'Masala': 'spicy', 'Ginger': 'zesty'},
#  'Tea': {'Green': 'Mind', 'Black': 'strong'}}

# %%
tea_shop["chai"]
# Out:
# {'Masala': 'spicy', 'Ginger': 'zesty'}

# %%
tea_shop["chai"]["Ginger"]
# Out:
# 'zesty'

# %%
sqr_nm = {x: x**2 for x in range(6)}
sqr_nm
# Out:
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

# %%
sqr_nm.clear()
sqr_nm
# Out:
# {}

# %%
keys = ["Masala", "Ginger", "Lemon"]
keys
# Out:
# ['Masala', 'Ginger', 'Lemon']

# %%
defaul_vale = "Delicious"

# %%
new_dict = dict.fromkeys(keys, defaul_vale)
new_dict
# Out:
# {'Masala': 'Delicious', 'Ginger': 'Delicious', 'Lemon': 'Delicious'}

# %%
tea_types = ("Black", "Green", "Oolang")
tea_types
# Out:
# ('Black', 'Green', 'Oolang')

# %%
tea_types[0]
# Out:
# 'Black'

# %%
tea_types[0] = "Lemon"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[118], line 1
# ----> 1 tea_types[0]='Lemon'
#
# TypeError: 'tuple' object does not support item assignment

# %%
more_tea = ("Herbal", "Earl Grey")
all_tea = more_tea + tea_types
all_tea
# Out:
# ('Herbal', 'Earl Grey', 'Black', 'Green', 'Oolang')

# %%
tea_types
# Out:
# ('Black', 'Green', 'Oolang')

# %%
(black, green, Oolang) = tea_types

# %%
black
# Out:
# 'Black'

# %%
user_score = int(input("Give  me a score value : "))
user_score / 2
# Out:
# 50.0

# %% [markdown]
# 1 . Project  : Age Group Categorization

# %%
age = input("Provide me an age : ")
age = int(age)
if age < 13:
    print("You are child !")
elif age >= 13 and age <= 19:
    print("You are Teenager !")
elif age >= 20 and age <= 59:
    print("You are Adult !")
else:
    print("You are Senior !")
# Out:
# You are Senior !

# %% [markdown]
# 2. Project : Movie Ticket pricing

# %%
# age = int(input("Provide me an age : "))
age = 18
day = True  # Wednesday
price = 12 if age >= 18 else 8
if day is True:
    # price=price-2
    price -= 2

print(f"Ticket price for you is ${price}")
# Out:
# Ticket price for you is $10

# %%
3.0

# %% [markdown]
# 3. Project : Fruit Ripeness Checker

# %%
fruit = "Banana"
color = "Yellow"
if fruit == "Banana":
    if color == "Green":
        print("Unripe")
    elif color == "Yellow":
        print("Ripe")
    elif color == "Brown":
        print("OverRipe")
else:
    print("Not found !")
# Out:
# Ripe
